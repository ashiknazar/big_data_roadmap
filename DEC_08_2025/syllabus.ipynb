# %% [markdown]
# # **6-Month Big Data Internship Program (2 Hours Daily)**
#
# ## **Month 1: Python, Linux, Git & SQL**
# ### Week 1 – Python Basics
# - Variables, loops, functions
# - OOP, exception handling
# - Virtual environments
#
# ### Week 2 – Python for Data Engineering
# - Numpy, Pandas
# - CSV, JSON handling
# - Data cleaning tasks
#
# ### Week 3 – Linux Essentials
# - Linux commands
# - Shell scripting
# - Automation with crontab
#
# ### Week 4 – SQL Basics
# - CRUD operations
# - Joins, subqueries
# - Using MySQL/SQLite
#
# ---
#
# ## **Month 2: Big Data Fundamentals + Hadoop Ecosystem**
# ### Week 1 – Big Data Concepts
# - 3Vs, OLTP vs OLAP
# - Batch vs Real-time
#
# ### Week 2 – Hadoop Architecture
# - HDFS, NameNode, DataNode
# - Replication, block storage
#
# ### Week 3 – Hadoop Ecosystem Tools
# - YARN, MapReduce
# - Hive, Sqoop, HBase
#
# ### Week 4 – Hive Deep Dive
# - Partitioning, bucketing
# - Query optimization
#
# ---
#
# ## **Month 3: Apache Spark + PySpark**
# ### Week 1 – Spark Core Concepts
# - RDDs, DAG, cluster managers
#
# ### Week 2 – PySpark DataFrames
# - Transformations, actions
# - Joins, aggregations
#
# ### Week 3 – Spark SQL
# - UDFs, window functions
#
# ### Week 4 – Spark Optimization
# - Catalyst optimizer
# - Partition strategies
#
# ---
#
# ## **Month 4: Kafka + Real-Time Data Streaming**
# ### Week 1 – Kafka Basics
# - Topics, partitions, consumers
#
# ### Week 2 – Kafka with Python
# - Producer & consumer code
#
# ### Week 3 – Spark Streaming
# - DStreams, Structured Streaming
#
# ### Week 4 – Real-Time Pipeline
# - Kafka → Spark → HDFS/Hive
#
# ---
#
# ## **Month 5: Cloud (AWS) + Data Pipelines**
# ### Week 1 – AWS Basics
# - EC2, S3, IAM
#
# ### Week 2 – AWS Data Tools
# - Glue, Lambda, S3 Data Lake
#
# ### Week 3 – CI/CD for Data Engineering
# - GitHub Actions
# - Docker basics
#
# ### Week 4 – Workflow Orchestration
# - Apache Airflow / Step Functions
#
# ---
#
# ## **Month 6: ML + Capstone Project**
# ### Week 1 – ML for Big Data
# - Spark MLlib basics
#
# ### Week 2 – Project Design
# - Architecture diagrams
#
# ### Week 3 – Capstone Implementation
# - Big Data project of choice
#
# ### Week 4 – Deployment & Evaluation
# - AWS deployment
# - Final presentation
#
# ---
#
# ## **Final Deliverables**
# - 1 Batch ETL Pipeline
# - 1 Kafka Real-Time Pipeline
# - 1 Cloud Data Pipeline
# - 1 Spark MLlib Model
# - Capstone Project (end-to-end)
# - GitHub Portfolio
# - Internship Certificate
