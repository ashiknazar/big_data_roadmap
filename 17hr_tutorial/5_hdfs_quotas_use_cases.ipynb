# %% [markdown]
# - Space quota
# - normal quota

# %% [markdown]
# ### space quota

# %% [markdown]
# `hadoop dfsadmin -setSpaceQuota 100 /tech`  100-bytes

# %% [markdown]
# `hadoop dfsadmin -clrSpaceQuota /tech`

# %% [markdown]
# - normal quota
#   - limit file count
#   - but can be any size
#   - `hadoop dfsadmin -setQuota 3 /tech`
#   - `hadoop dfsadmin -clrQuota /tech`

# %% [markdown]
# - `hadoop fs -count -q -h -v /tech`

# %% [markdown]
# ___

# %% [markdown]
# - 1,gowtham
# - 1,saravana
# - select * from table where roll=1
#   - even we get **new** file in hive , old file is also existing , we have compaction to remove old
