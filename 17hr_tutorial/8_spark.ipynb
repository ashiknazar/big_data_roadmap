# %% [markdown]
#    - spark
#    - sparksql (sql query engine)
#    - spark streaming  #opp to batch processing
#    -
#    - mlib
#    - graphx
#    -

# %% [markdown]
# - before spark storm warm used for streaming
# - spark support both batch processing and stream processing
# - hadoop was using batch processing
# -
